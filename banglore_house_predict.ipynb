# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-9c910b5f-355c-484e-a941-defe3bd3f122" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9c910b5f-355c-484e-a941-defe3bd3f122">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving house_price.csv to house_price (2).csv

# %%
df=pd.read_csv('house_price.csv')
df.head()
# Out:
#    Unnamed: 0      Location  BHK  Furnishing  Sq.ft  Old(years)  Floor  Price
# 0          37  Bommanahalli    3           1   3000           1      3  28000
# 1          43  Bommanahalli    3           1   1650          10      0  18000
# 2          12    Whitefield    2           0   1000           5      3  16400
# 3           8    Whitefield    3           0   1600           1      9  27000
# 4           9    Whitefield    2           1   1200           5      1  20000

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.head()
# Out:
#    Unnamed: 0      Location  BHK  Furnishing  Sq.ft  Old(years)  Floor  Price
# 0          37  Bommanahalli    3           1   3000           1      3  28000
# 1          43  Bommanahalli    3           1   1650          10      0  18000
# 2          12    Whitefield    2           0   1000           5      3  16400
# 3           8    Whitefield    3           0   1600           1      9  27000
# 4           9    Whitefield    2           1   1200           5      1  20000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1000 non-null   int64
#  1   Location    1000 non-null   object
#  2   BHK         1000 non-null   int64
#  3   Furnishing  1000 non-null   int64
#  4   Sq.ft       1000 non-null   int64
#  5   Old(years)  1000 non-null   int64
#  6   Floor       1000 non-null   int64
#  7   Price       1000 non-null   int64
# dtypes: int64(7), object(1)
# memory usage: 62.6+ KB

# %%
#df=df.iloc[:,1:]#we need to eliminate first col and include all rows
#df
df=df.drop(['Unnamed: 0'],axis=1)
#df1=df1.drop(['Name','PassengerId','Ticket','Embarked'],axis=1)

# %%
from sklearn import preprocessing 
le=preprocessing.LabelEncoder()
df['Location']=le.fit_transform(df['Location'])# do onehot encode
#df['Location'].value_counts()

# %%
df
# Out:
#      Location  BHK  Furnishing  Sq.ft  Old(years)  Floor  Price
# 0           0    3           1   3000           1      3  28000
# 1           0    3           1   1650          10      0  18000
# 2           1    2           0   1000           5      3  16400
# 3           1    3           0   1600           1      9  27000
# 4           1    2           1   1200           5      1  20000
# ..        ...  ...         ...    ...         ...    ...    ...
# 995         0    3           1   1460           1      2  25000
# 996         1    3           0   2100           1      7  28000
# 997         0    2           0   1033           5      0  16500
# 998         0    3           0   1500          10      1  22000
# 999         1    3           1   1768           5     11  30000
#
# [1000 rows x 7 columns]

# %%
X=df[['Location','BHK','Furnishing','Sq.ft','Old(years)','Floor']]#define x
Y=df['Price']
print(X)
print(Y)
# Out:
#      Location  BHK  Furnishing  Sq.ft  Old(years)  Floor
# 0           0    3           1   3000           1      3
# 1           0    3           1   1650          10      0
# 2           1    2           0   1000           5      3
# 3           1    3           0   1600           1      9
# 4           1    2           1   1200           5      1
# ..        ...  ...         ...    ...         ...    ...
# 995         0    3           1   1460           1      2
# 996         1    3           0   2100           1      7
# 997         0    2           0   1033           5      0
# 998         0    3           0   1500          10      1
# 999         1    3           1   1768           5     11
#
# [1000 rows x 6 columns]
# 0      28000
# 1      18000
# 2      16400
# 3      27000
# 4      20000
#        ...
# 995    25000
# 996    28000
# 997    16500
# 998    22000
# 999    30000
# Name: Price, Length: 1000, dtype: int64

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.2)

# %%
X.shape
# Out:
# (1000, 6)

# %%
Y.shape
# Out:
# (1000,)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred=lr.predict(xtest)
pred
# Out:
# array([30327.06357421, 22310.23079517, 21476.17024476, 36337.56980609,
#        15560.60114341, 15328.08551571, 22216.08431385, 33666.88516619,
#        18071.73034568, 18815.46349179, 17292.84246875, 22216.08431385,
#        26214.75791182, 18892.39341688, 16418.42809288, 18737.52834687,
#        37900.03087512, 14552.34102989, 18468.85406074, 18071.73034568,
#        16418.42809288, 13762.87004833, 28310.75686215, 22216.08431385,
#        22536.78366926, 30327.06357421, 22216.08431385, 15328.08551571,
#        17292.84246875, 19295.61839601, 22509.14886137, 21765.78094389,
#        32154.6986957 , 16418.42809288, 15560.60114341, 14251.97007443,
#        18815.46349179, 17292.84246875, 39760.55589281, 22310.23079517,
#        15560.60114341, 18892.39341688, 24445.15699727, 28310.75686215,
#        24445.15699727, 21765.78094389, 33248.28100347, 21765.78094389,
#        18815.46349179, 28310.75686215, 14251.97007443, 25741.77881992,
# ...

# %%
from sklearn.metrics import mean_squared_error
m=mean_squared_error(ytest,pred)
rmse=np.sqrt(m)
rmse
# Out:
# 2957.7194269777924

# %%
print(ytest)
# Out:
# 512    27000
# 912    21000
# 717    25000
# 0      28000
# 873    16000
#        ...
# 723    15500
# 707    14000
# 774    16000
# 866    28000
# 979    16000
# Name: Price, Length: 200, dtype: int64

# %%
#from sklearn.metrics import r2_score
#r2_score(y_true, y_pred)
